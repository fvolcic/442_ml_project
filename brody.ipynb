# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import importlib
import torch.optim as optim

FORCE_CPU = False

if FORCE_CPU:
    device = torch.device("cpu")
else:
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

if (device.type == "cpu"):
  print("Using CPU!")

# %%
import models.unet_AI
importlib.reload(models.unet_AI)
import utils.utils as utils
from utils.utils import *
from dataloaders.NYU_loader import get_dataloaders

# %%
train_dl, test_dl = get_dataloaders()
# Out:
# ...
#   0%|          | 0/2972037809 [00:00<?, ?it/s]
# Done!

# %%
unet = models.unet_AI.UNetAI(n_channels=4, n_classes=13).to(device=device)
models.unet_AI.train_UNet_AI(unet, train_dl, 10)
# Out:
# 100%|██████████| 50/50 [01:09<00:00,  1.38s/it]
# [1/10] - using time: 69.24 seconds
# loss of generator G: 0.723
#  66%|██████▌   | 33/50 [01:01<00:31,  1.86s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-38a810dcff6d> in <module>
#       1 unet = models.unet_AI.UNetAI(n_channels=4, n_classes=13).to(device=device)
# ----> 2 models.unet_AI.train_UNet_AI(unet, train_dl, 10)
#
# ~/442/SemanticSegmentationProject/models/unet_AI.py in train_UNet_AI(model, train_loader, num_epochs)
#     110         epoch_start_time = time.time()
#     111         batch_idx = 0
# --> 112         for data in tqdm(train_loader):
#     113             input = data[0].to(device=device) # images
#     114
#
# ~/.local/lib/python3.8/site-packages/tqdm/std.py in __iter__(self)
#    1193
#    1194         try:
# -> 1195             for obj in iterable:
# ...
